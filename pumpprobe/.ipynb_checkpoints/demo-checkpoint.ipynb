# %%
import pump_probe

# %%
import numpy as np
import pandas as pd
import scipy as sci

from matplotlib import pyplot as plt
from scipy.optimize import curve_fit
from matplotlib.pyplot import MultipleLocator

# %%
from pump_probe.filesort import file_sort

# %%
f_path = 'data/power/'
power_from = 0
power_to = -12

file_info = {
    "f_path":f_path,
    "power_from": power_from,
    "power_to": power_to,
    "reverse": True,
}

# %%
files = file_sort(file_info)

# %%
from pump_probe.filedata import FileData as fileData

# %%
fileData_list = []
for file in files:
    file_name = file_info["f_path"] + file
    fileData_list.append(fileData(file, file_info))

# %%
Time = np.array([])
Value_t = np.array([])
temp_THG = np.zeros(len(files))
E_THG = np.zeros(len(files))
n_files = len(files)

Color_R = np.append(np.linspace(227,34,5),np.linspace(37,0,5))
Color_R = np.append(Color_R,np.linspace(1,0,5))
Color_R = np.append(Color_R,np.linspace(1,230,5))
Color_R = np.append(Color_R,np.linspace(230,229,5))

Color_G = np.append(np.linspace(0,34,5),np.linspace(35,160,5))
Color_G = np.append(Color_G,np.linspace(161,151,5))
Color_G = np.append(Color_G,np.linspace(150,230,5))
Color_G = np.append(Color_G,np.linspace(230,31,5))

Color_B = np.append(np.linspace(126,136,5),np.linspace(135,223,5))
Color_B = np.append(Color_B,np.linspace(222,75,5))
Color_B = np.append(Color_B,np.linspace(74,0,5))
Color_B = np.append(Color_B,np.linspace(1,31,5))

Color_R = Color_R[::-1]/255
Color_G = Color_G[::-1]/255
Color_B = Color_B[::-1]/255

# bg
# file_bg = os.listdir('data/bg/')
# data_bg = np.loadtxt('data/bg/'+file_bg[0])
# value_t_bg = data_bg[:,2]
value_t_bg = 0
plt.figure(figsize=(16,12))
i = 0
plt.rcParams['xtick.direction'] = 'in' 
plt.rcParams['ytick.direction'] = 'in' 

shift = 0.05

for fileData in fileData_list:
    position = fileData.position
    time = fileData.time
#         time = data[0:-cut_time,0]
    value_t = fileData.value
    power = fileData.power
#         value_t = value_t[::-1]

#         (fre, value_f) = fourier_transfer(time, value_t)
#         if temp == 13.3:
#             x_13d3 = time
#             y_13d3 = value_t
#             i_13d3 = i
    color_red = Color_R[i]
    color_green = Color_G[i]
    color_blue = Color_B[i]

#         if power > 0:

    value_t = 20*value_t
#         print(color_red)
    if i <3:
        value_t = value_t*0.3
        plt.text(time[-1]-2,value_t[-1]+0.2,r'$\times$0.3',fontdict={'size':'28','color':[color_red,color_green,color_blue]})
    if i == len(files)-1:
        plt.plot(time,value_t+0*(len(files)-i-1),label=str(int(power*10))+r" $\mu$J cm$^{-2}$",color=[color_red,color_green,color_blue],linewidth=3)
    else:
        plt.plot(time,value_t+0*(len(files)-i-1),label=str(int(power*10)),color=[color_red,color_green,color_blue],linewidth=3)

#         plt.text(-5,(shift)*(len(files)-i-1),str(power*10)+' ',fontdict={'size':'28','color':[color_red,color_green,color_blue]})
    i += 1
# plt.title("Temperature dependent",fontsize=20)
plt.xticks(fontsize=40)
plt.yticks(fontsize=40)
plt.xlabel('Time Delay (ps)',fontsize=40)
plt.ylabel(r'$\Delta$R/R (10$^{-4}$)',fontsize=40)
# plt.ylabel('E/uV',fontsize=40)
# plt.xlim(-1.0,1)
plt.legend(fontsize=17,frameon=False,loc='lower left')

set_lw = 3
ax=plt.gca()

ax.spines['bottom'].set_linewidth(set_lw)
ax.spines['left'].set_linewidth(set_lw)
ax.spines['right'].set_linewidth(set_lw)
ax.spines['top'].set_linewidth(set_lw)


for tickline in ax.xaxis.get_ticklines():
    tickline.set_markersize(10)
    tickline.set_markeredgewidth(5)
for tickline in ax.yaxis.get_ticklines():
    tickline.set_markersize(10)
    tickline.set_markeredgewidth(5)
ax.yaxis.set_ticks_position("left")
ax.xaxis.set_ticks_position("bottom")


plt.savefig('output/Power dependent time domain.eps',bbox_inches = 'tight')
plt.show()
